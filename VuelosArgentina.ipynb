# %% [markdown]
# #### Ejercicio de análisis de datos realizado en Python.
# 1. El archivo que contiene los datos se puede descargar desde aquí: https://datos.transporte.gob.ar/dataset/aterrizajes-y-despegues-procesados-por-anac
# 2. El archivo usado contiene un listado de los distintos vuelos realizados en el año 2021, en Argentina.
# 3. Usé Jupyter Netbook (Anaconda3) y las librerias Pandas, Numpy, Seaborn y MatPlotLib.
# 4. Usé los datos para realizar distintas clases de gráficos.

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
vuelosArgentina=pd.read_excel("202111-informe-ministerio.xlsx")
vuelosArgentina
# Out:
#             Fecha  Hora UTC     Clase de Vuelo (todos los vuelos)  \
# 0      2021-01-01  00:02:00  Vuelo Privado con Matrícula Nacional
# 1      2021-01-01  00:24:00                               Regular
# 2      2021-01-01  00:26:00                               Regular
# 3      2021-01-01  00:29:00                               Regular
# 4      2021-01-01  00:37:00                               Regular
# ...           ...       ...                                   ...
# 288778 2021-11-30  23:45:00  Vuelo Privado con Matrícula Nacional
# 288779 2021-11-30  23:56:00                               Regular
# 288780 2021-11-30  23:58:00                               Regular
# 288781 2021-11-30  23:59:00                Vuelo Oficial Nacional
# 288782 2021-11-30  23:59:00                               Regular
#
#        Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0                Domestico           Despegue        PAR              ROS
# ...

# %%
funciones_columnas=['Pasajeros']

for f in funciones_columnas:
    fig = plt.figure(figsize = (12,4))
    sb.barplot(x='Clase de Vuelo (todos los vuelos)', y=f, data=vuelosArgentina)
    plt.xticks(rotation=90) 
    plt.grid()
    plt.title(f)
    plt.show()

# %%
funciones_columnas=['Pasajeros']

for f in funciones_columnas:
    fig = plt.figure(figsize = (12,4))
    sb.barplot(x='Clasificación Vuelo', y=f, data=vuelosArgentina)
    plt.xticks(rotation=90) 
    plt.grid()
    plt.title(f)
    plt.show()

# %%
funciones_columnas=['Pasajeros']

for f in funciones_columnas:
    fig = plt.figure(figsize = (12,4))
    sb.barplot(x='Tipo de Movimiento', y=f, data=vuelosArgentina)
    plt.xticks(rotation=90) 
    plt.grid()
    plt.title(f)
    plt.show()

# %%
funciones_columnas=['Pasajeros']

for f in funciones_columnas:
    fig = plt.figure(figsize = (12,4))
    sb.barplot(x='Aeropuerto', y=f, data=vuelosArgentina)
    plt.xticks(rotation=90) 
    plt.grid()
    plt.title(f)
    plt.show()

# %%
tablaGlobal=vuelosArgentina
tablaGlobal["Tiempo"]=tablaGlobal["Fecha"].astype(str)
tablaGlobal["Año"]=tablaGlobal["Tiempo"].str[0:4]
tablaGlobal["Mes"]=tablaGlobal["Tiempo"].str[5:7]
tablaGlobal["Día"]=tablaGlobal["Tiempo"].str[8:10]
##tablaGlobal

# %%
funciones_columnas=['Pasajeros']

for f in funciones_columnas:
    fig = plt.figure(figsize = (30,10))
    sb.barplot(x='Mes', y=f, data=vuelosArgentina)
    plt.xticks(rotation=90) 
    plt.grid()
    plt.title(f)
    plt.show()
